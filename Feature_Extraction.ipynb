# %%
 # pip uninstall opencv-contrib-python

# %%
# pip install -U opencv-contrib-python==3.4.2.17 #PARA SURF

# %%
 # pip install opencv-contrib-python #PARA SIFT

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import cv2

from skimage import io
from io import BytesIO
from PIL import Image

from google.colab.patches import cv2_imshow

# %%
cv2.__version__
# Out:
# '4.5.5'

# %% [markdown]
# ##Preparación de Imagen

# %%
#Getting the reference image ready for feature detection

url = 'https://raw.githubusercontent.com/DavidGlezGmz/Computer-Vision/main/Images/Robot.jpg'
input_image = io.imread(url) 
cv2_imshow(input_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x800 at 0x7F1EA3AF3C50>

# %%
input_image.shape
# Out:
# (800, 1200, 3)

# %%
input_image = cv2.resize(input_image, (700,550),interpolation=cv2.INTER_AREA)
cv2_imshow(input_image)
#print(input_image)
# Out:
# <PIL.Image.Image image mode=RGB size=700x550 at 0x7F1EA358EB90>

# %%
gray_image = cv2.cvtColor(input_image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
#print(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=700x550 at 0x7F1EA3576AD0>

# %%
gray_image.shape
# Out:
# (550, 700)

# %% [markdown]
# ##SIFT

# %%
sift = cv2.SIFT_create()

# %%
kp = sift.detect(gray_image,None)

# %%
img=cv2.drawKeypoints(gray_image,kp,input_image,flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=700x550 at 0x7F1EA35A4F50>

# %% [markdown]
# ##ORB

# %%
orb = cv2.ORB_create(5000)

# %%
keypoints_orb, descriptors_orb = orb.detectAndCompute(gray_image, None)

# %%
final_keypoints_orb = cv2.drawKeypoints(gray_image, keypoints_orb, input_image, (0,255,0))

# %%
cv2_imshow(final_keypoints_orb)
# Out:
# <PIL.Image.Image image mode=RGB size=700x550 at 0x7F1EA126BC10>

# %% [markdown]
# ##SURF

# %%
surf = cv2.xfeatures2d.SURF_create(5000)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-38-8bb2defc320f> in <module>()
# ----> 1 surf = cv2.xfeatures2d.SURF_create(5000)
#
# error: OpenCV(4.5.5) /io/opencv_contrib/modules/xfeatures2d/src/surf.cpp:1027: error: (-213:The function/feature is not implemented) This algorithm is patented and is excluded in this configuration; Set OPENCV_ENABLE_NONFREE CMake option and rebuild the library in function 'create'

# %%
kp, des = surf.detectAndCompute(input_image,None)

# %%
len(kp)

# %%
img2 = cv2.drawKeypoints(gray_image,kp,None,(255,0,0),4)

# %%
cv2_imshow(img2)
